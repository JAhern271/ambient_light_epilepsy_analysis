# %% [markdown]
# # 07 - LUX analysis
#
# **No analysis runs in this notebook.** The full analysis processes several hundred
# participants and is too slow to run interactively, so it lives in a script:
#
# ```
# python scripts/lux_analysis.py --downsample 5min
# ```
#
# The 1 Hz version is run on BlueBEAR. Output goes to a dated directory under the analysis
# root, with a `.provenance.json` sidecar recording the git commit, machine and parameters
# used. Results are analysed in notebook 08.
